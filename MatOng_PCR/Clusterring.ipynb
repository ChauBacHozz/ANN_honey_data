# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("PCA40_data.xlsx")
df.head()
# Out:
#    Unnamed: 0           0          1          2          3          4  \
# 0           0  129.286059 -31.989545 -42.577313  14.876528  10.281361
# 1           1  -30.632848 -75.854620  29.430294  66.214643  65.027294
# 2           2  129.282246  88.151047 -22.523880 -22.052108  -4.411597
# 3           3 -122.405524 -18.036617  27.043453  17.675188   3.657985
# 4           4  -62.623697  -3.090748  18.169009 -18.327745   3.315433
#
#            5          6          7          8  ...         30         31  \
# 0  -2.170514  -0.115848   2.866769  -8.440631  ...   8.905295   5.245880
# 1  18.293040  22.904148  70.051056   9.952642  ...   1.786751  11.186402
# 2  -1.496015  -5.196344  28.647171  -3.867099  ... -13.349190  20.851679
# 3  -6.540768   1.643937 -27.470602   0.369963  ...  -6.111662  -8.200229
# 4 -29.507747   2.934109  -0.660330 -22.044401  ...  -5.110396 -17.149159
#
#           32        33         34         35         36         37         38  \
# ...

# %%
labels = pd.read_excel("labels.xlsx")
labels
# Out:
#     Unnamed: 0  0
# 0            0  1
# 1            1  2
# 2            2  1
# 3            3  0
# 4            4  2
# ..         ... ..
# 57          57  1
# 58          58  2
# 59          59  0
# 60          60  1
# 61          61  0
#
# [62 rows x 2 columns]

# %%
df.iloc[:, 0] = labels.iloc[:, 1]

# %%
df.head()
# Out:
#    Unnamed: 0           0          1          2          3          4  \
# 0           1  129.286059 -31.989545 -42.577313  14.876528  10.281361
# 1           2  -30.632848 -75.854620  29.430294  66.214643  65.027294
# 2           1  129.282246  88.151047 -22.523880 -22.052108  -4.411597
# 3           0 -122.405524 -18.036617  27.043453  17.675188   3.657985
# 4           2  -62.623697  -3.090748  18.169009 -18.327745   3.315433
#
#            5          6          7          8  ...         30         31  \
# 0  -2.170514  -0.115848   2.866769  -8.440631  ...   8.905295   5.245880
# 1  18.293040  22.904148  70.051056   9.952642  ...   1.786751  11.186402
# 2  -1.496015  -5.196344  28.647171  -3.867099  ... -13.349190  20.851679
# 3  -6.540768   1.643937 -27.470602   0.369963  ...  -6.111662  -8.200229
# 4 -29.507747   2.934109  -0.660330 -22.044401  ...  -5.110396 -17.149159
#
#           32        33         34         35         36         37         38  \
# ...

# %%
df.to_excel("MatOng_PCA40.xlsx")
